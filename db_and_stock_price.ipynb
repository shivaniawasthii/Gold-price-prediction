# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns

# %%
api_key = "Q31L72QEQ8JUGY6O"
symbol = "AAPL"
function = "TIME_SERIES_DAILY"
url = f"https://www.alphavantage.co/query?function={function}&symbol=SBIN&apikey={api_key}"
response = requests.get(url)
data = response.json()
print(data)
# df_stock_prices = pd.DataFrame(data["Time Series (Daily)"]).T
# df_stock_prices.index = pd.to_datetime(df_stock_prices.index)
# Out:
# {'Error Message': 'Invalid API call. Please retry or visit the documentation (https://www.alphavantage.co/documentation/) for TIME_SERIES_DAILY.'}

# %%
import pandas as pd

# Assuming your DataFrames are named df1 and df2
# Replace 'df1' and 'df2' with the actual names of your DataFrames

# Creating sample DataFrames
data1 = {'A': [1, 2, 3],
         'B': [4, 5, 6]}
df1 = pd.DataFrame(data1)

data2 = {'A': [7, 8, 9],
         'B': [10, 11, 12]}
df2 = pd.DataFrame(data2)

display(df1)
display(df2)

# Concatenating the two DataFrames vertically
combined_df = pd.concat([df1, df2])

# Printing the combined DataFrame
print(combined_df)
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
#    A   B
# 0  7  10
# 1  8  11
# 2  9  12
#    A   B
# 0  1   4
# 1  2   5
# 2  3   6
# 0  7  10
# 1  8  11
# 2  9  12
